# %%
# pip uninstall -y autorom ale-py gym gymnasium
# pip install "gymnasium[atari,accept-rom-license]" "autorom>=0.6.1" "ale-py>=0.8.1"
# AutoROM --accept-license
# pip install stable-baselines3[extra]

# %%
from stable_baselines3 import DQN
import gymnasium as gym
import ale_py

# %% [markdown]
# - DQN in stable baseline3 has total 3 policies i.e. inbuilt 3 Deep Neural Net architectures are defined
#     - MlpPolicy - MLP Dense Layer
#     - CNNPolicy - CNN with Dense Layer
#     - MultiInputPolicy -

# %%
model = DQN("MlpPolicy", "MountainCar-v0", verbose=1, device="cuda")

# %%
model.learn(total_timesteps=1000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8296     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 86       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 869      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 141      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# ...

# %%
model.action_space.sample()
# Out:
# np.int64(0)

# %%
env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")  # modern alias

# %%
model = DQN("CnnPolicy", env, buffer_size=100000,   # 🔽 reduce from 1e6 to 1e5 or even 5e4
            learning_starts=50000,verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# c:\Users\ytiam\notebooks\.venv\Lib\site-packages\stable_baselines3\common\buffers.py:242: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 20.16GB > 3.03GB
#   warnings.warn(

# %%
model.policy
# Out:
# CnnPolicy(
#   (q_net): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#         (5): ReLU()
#         (6): Flatten(start_dim=1, end_dim=-1)
#       )
#       (linear): Sequential(
#         (0): Linear(in_features=22528, out_features=512, bias=True)
#         (1): ReLU()
#       )
#     )
#     (q_net): Sequential(
#       (0): Linear(in_features=512, out_features=4, bias=True)
#     )
#   )
#   (q_net_target): QNetwork(
#     (features_extractor): NatureCNN(
#       (cnn): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(8, 8), stride=(4, 4))
#         (1): ReLU()
#         (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#         (3): ReLU()
#         (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
# ...
