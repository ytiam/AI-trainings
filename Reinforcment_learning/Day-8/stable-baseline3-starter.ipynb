# %%
from stable_baselines3 import DQN

model = DQN("MlpPolicy", "MountainCar-v0", verbose=1, device="cuda")
# Out:
# Using cpu device
# Creating environment from the given name 'MountainCar-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.5     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 8296     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 86       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 17.6     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 869      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 141      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 10       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 14.8     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 905      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 177      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.501    |
# |    n_updates        | 19       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.6     |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 908      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 217      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.438    |
# |    n_updates        | 29       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 924      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 257      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.419    |
# |    n_updates        | 39       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 12.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 956      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 296      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.391    |
# |    n_updates        | 48       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 975      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 336      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.321    |
# |    n_updates        | 58       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 11.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 987      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 377      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.302    |
# |    n_updates        | 69       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 995      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 414      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.314    |
# |    n_updates        | 78       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1003     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 455      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 88       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1004     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 493      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 98       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1010     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 533      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.251    |
# |    n_updates        | 108      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1013     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 569      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 117      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1022     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 607      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.191    |
# |    n_updates        | 126      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1020     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 645      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 136      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1024     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 680      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 144      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1022     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 718      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.149    |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.5     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1028     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 754      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 163      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1034     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 792      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.127    |
# |    n_updates        | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1038     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 831      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 182      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1039     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 869      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1039     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 908      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 201      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1040     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 943      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.075    |
# |    n_updates        | 210      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1046     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 984      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0779   |
# |    n_updates        | 220      |
# ----------------------------------

# %%
model.action_space.sample()
# Out:
# np.int64(0)

# %%
model = DQN("CnnPolicy", "BreakoutNoFrameskip-v4", verbose=1)
# Out:
# Using cpu device
# Creating environment from the given name 'BreakoutNoFrameskip-v4'
# ---------------------------------------------------------------------------
# NameNotFound                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model = DQN("CnnPolicy", "BreakoutNoFrameskip-v4", verbose=1)
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\stable_baselines3\dqn\dqn.py:106, in DQN.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, n_steps, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, stats_window_size, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#      77 def __init__(
#      78     self,
#      79     policy: Union[str, type[DQNPolicy]],
#    (...)    104     _init_setup_model: bool = True,
#     105 ) -> None:
# --> 106     super().__init__(
#     107         policy,
#     108         env,
#     109         learning_rate,
#     110         buffer_size,
#     111         learning_starts,
#     112         batch_size,
#     113         tau,
#     114         gamma,
#     115         train_freq,
#     116         gradient_steps,
#     117         action_noise=None,  # No action noise
#     118         replay_buffer_class=replay_buffer_class,
#     119         replay_buffer_kwargs=replay_buffer_kwargs,
#     120         optimize_memory_usage=optimize_memory_usage,
#     121         n_steps=n_steps,
#     122         policy_kwargs=policy_kwargs,
#     123         stats_window_size=stats_window_size,
#     124         tensorboard_log=tensorboard_log,
#     125         verbose=verbose,
#     126         device=device,
#     127         seed=seed,
#     128         sde_support=False,
#     129         supported_action_spaces=(spaces.Discrete,),
#     130         support_multi_env=True,
#     131     )
#     133     self.exploration_initial_eps = exploration_initial_eps
#     134     self.exploration_final_eps = exploration_final_eps
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:112, in OffPolicyAlgorithm.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, action_noise, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, n_steps, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, use_sde_at_warmup, sde_support, supported_action_spaces)
#      81 def __init__(
#      82     self,
#      83     policy: Union[str, type[BasePolicy]],
#    (...)    110     supported_action_spaces: Optional[tuple[type[spaces.Space], ...]] = None,
#     111 ):
# --> 112     super().__init__(
#     113         policy=policy,
#     114         env=env,
#     115         learning_rate=learning_rate,
#     116         policy_kwargs=policy_kwargs,
#     117         stats_window_size=stats_window_size,
#     118         tensorboard_log=tensorboard_log,
#     119         verbose=verbose,
#     120         device=device,
#     121         support_multi_env=support_multi_env,
#     122         monitor_wrapper=monitor_wrapper,
#     123         seed=seed,
#     124         use_sde=use_sde,
#     125         sde_sample_freq=sde_sample_freq,
#     126         supported_action_spaces=supported_action_spaces,
#     127     )
#     128     self.buffer_size = buffer_size
#     129     self.batch_size = batch_size
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\stable_baselines3\common\base_class.py:169, in BaseAlgorithm.__init__(self, policy, env, learning_rate, policy_kwargs, stats_window_size, tensorboard_log, verbose, device, support_multi_env, monitor_wrapper, seed, use_sde, sde_sample_freq, supported_action_spaces)
#     167 # Create and wrap the env if needed
#     168 if env is not None:
# --> 169     env = maybe_make_env(env, self.verbose)
#     170     env = self._wrap_env(env, self.verbose, monitor_wrapper)
#     172     self.observation_space = env.observation_space
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\stable_baselines3\common\base_class.py:61, in maybe_make_env(env, verbose)
#      59 # Set render_mode to `rgb_array` as default, so we can record video
#      60 try:
# ---> 61     env = gym.make(env_id, render_mode="rgb_array")
#      62 except TypeError:
#      63     env = gym.make(env_id)
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\gymnasium\envs\registration.py:681, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     678     assert isinstance(id, str)
#     680     # The environment name can include an unloaded module in "module:env_name" style
# --> 681     env_spec = _find_spec(id)
#     683 assert isinstance(env_spec, EnvSpec)
#     685 # Update the env spec kwargs with the `make` kwargs
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\gymnasium\envs\registration.py:526, in _find_spec(env_id)
#     520     logger.warn(
#     521         f"Using the latest versioned environment `{new_env_id}` "
#     522         f"instead of the unversioned environment `{env_name}`."
#     523     )
#     525 if env_spec is None:
# --> 526     _check_version_exists(ns, name, version)
#     527     raise error.Error(
#     528         f"No registered env with id: {env_name}. Did you register it, or import the package that registers it? Use `gymnasium.pprint_registry()` to see all of the registered environments."
#     529     )
#     531 return env_spec
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\gymnasium\envs\registration.py:392, in _check_version_exists(ns, name, version)
#     389 if get_env_id(ns, name, version) in registry:
#     390     return
# --> 392 _check_name_exists(ns, name)
#     393 if version is None:
#     394     return
#
# File c:\Users\ytiam\notebooks\.venv\Lib\site-packages\gymnasium\envs\registration.py:369, in _check_name_exists(ns, name)
#     366 namespace_msg = f" in namespace {ns}" if ns else ""
#     367 suggestion_msg = f" Did you mean: `{suggestion[0]}`?" if suggestion else ""
# --> 369 raise error.NameNotFound(
#     370     f"Environment `{name}` doesn't exist{namespace_msg}.{suggestion_msg}"
#     371 )
#
# NameNotFound: Environment `BreakoutNoFrameskip` doesn't exist.

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# !nvidia-smi
# Out:
# Sun Oct 26 09:58:19 2025
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 497.29       Driver Version: 497.29       CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   51C    P8     6W /  N/A |    164MiB /  6144MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
